# %% [markdown]
# # Try scraping prices of 18 housing on first page

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# %%
#Scrape first page: price from 100-199
url='https://www.airbnb.com/s/Manhattan--New-York--NY--United-States/homes?refinement_paths%5B%5D=%2Fhomes&adults=1&children=0&infants=0&toddlers=0&query=Manhattan%2C%20New%20York%2C%20NY%2C%20United%20States&allow_override%5B%5D=&price_min=100&price_max=199&s_tag=bRa2iowc'
driver = webdriver.Chrome('/Users/yutingzhang/Desktop/ops_con/chromedriver')
driver.implicitly_wait(10) #gives an implicit wait for 15 seconds
driver.get(url)

#get prices of page_one housings

prices=driver.find_elements(By.XPATH,"//span[@class='_pd52isb']")
price=[element.text for element in prices]

#loop through pages to get prices

base_url="https://www.airbnb.com/"
#driver.implicitly_wait(10)
for num in range(2,18):
    element=driver.find_element(By.XPATH,"//a/li[@data-id="page-"+str(num)]")
    #get the next page url
    new_url=base_url+element.getAttribute('href')
    driver.implicitly_wait(10) #gives an implicit wait for 15 seconds
    driver.get(new_url)
    for new_p in driver.find_elements(By.XPATH,"//span[@class='_pd52isb']")
    
    
    

driver.close()

# %%
#put the scrape data in df
price=[element[6:] for element in price]
df1=pd.DataFrame()
#df1['Room Type']=room_type
df1['Price']=price
df1
# Out:
#    Price
# 0   $153
# 1   $110
# 2   $135
# 3   $110
# 4   $100
# 5   $150
# 6   $159
# 7   $100
# 8   $178
# 9   $159
# 10  $140
# 11  $100
# 12  $100
# 13  $150
# 14  $199
# 15  $125
# 16  $119
# 17  $165

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re

# %%
url='https://www.airbnb.com/s/Manhattan--New-York--NY--United-States/homes?refinement_paths%5B%5D=%2Fhomes&adults=1&children=0&infants=0&toddlers=0&query=Manhattan%2C%20New%20York%2C%20NY%2C%20United%20States&allow_override%5B%5D=&s_tag=eDYv73-q'
response = requests.get(url)
results_page = BeautifulSoup(response.content,'lxml')
#prices=re.search('',reponse.text)
prices=results_page.find('span',class_='_doc79r')
#price=[element.text for element in prices]
